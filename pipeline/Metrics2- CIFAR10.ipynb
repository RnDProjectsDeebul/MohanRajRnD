# %%
# ce_loss_acc_path                = '../results/Crossentropy_LeNet_loss_acc.csv'
# edl_mse_loss_acc_path           = '../results/Evidential_MSE_LeNet_loss_acc.csv'
# edl_log_loss_acc_path           = '../results/Evidential_LOG_LeNet_loss_acc.csv'
# edl_digamma_loss_acc_path       = '../results/Evidential_DIGAMMA_LeNet_loss_acc.csv'
         
# ce_entropy_path                 = '../results/Crossentropy_LeNet_entropy.csv'
# ce_q_entropy_path               = '../results/Crossentropy_LeNet_quant_entropy.csv'
# edl_mse_entropy_path            = '../results/Evidential_MSE_LeNet_entropy.csv'
# edl_mse_q_entropy_path          = '../results/Evidential_MSE_LeNet_quant_entropy.csv'
# edl_log_entropy_path            = '../results/Evidential_LOG_LeNet_entropy.csv'
# edl_log_q_entropy_path          = '../results/Evidential_LOG_LeNet_quant_entropy.csv'
# edl_digamma_entropy_path        = '../results/Evidential_DIGAMMA_LeNet_entropy.csv'
# edl_digamma_q_entropy_path      = '../results/Evidential_DIGAMMA_LeNet_quant_entropy.csv'
         
# ce_metrics_path                 = '../results/Crossentropy_LeNet_metrics.csv'
# ce_q_metrics_path               = '../results/Crossentropy_LeNet_quant_metrics.csv'
# edl_mse_metrics_path            = '../results/Evidential_MSE_LeNet_metrics.csv'
# edl_mse_q_metrics_path          = '../results/Evidential_MSE_LeNet_quant_metrics.csv'
# edl_log_metrics_path            = '../results/Evidential_LOG_LeNet_metrics.csv'
# edl_log_q_metrics_path          = '../results/Evidential_LOG_LeNet_quant_metrics.csv'
# edl_digamma_metrics_path        = '../results/Evidential_DIGAMMA_LeNet_metrics.csv'
# edl_digamma_q_metrics_path      = '../results/Evidential_DIGAMMA_LeNet_quant_metrics.csv'

# file_ext = ' MNIST.png'
# save_pth = '../results/MNIST/'

# %%
ce_loss_acc_path                = '../results/Crossentropy_Resnet18_loss_acc.csv'
edl_mse_loss_acc_path           = '../results/Evidential_MSE_Resnet18_loss_acc.csv'
edl_log_loss_acc_path           = '../results/Evidential_LOG_Resnet18_loss_acc.csv'
edl_digamma_loss_acc_path       = '../results/Evidential_DIGAMMA_Resnet18_loss_acc.csv'
         
ce_entropy_path                 = '../results/Crossentropy_Resnet18_entropy.csv'
ce_q_entropy_path               = '../results/Crossentropy_Resnet18_quant_entropy.csv'
edl_mse_entropy_path            = '../results/Evidential_MSE_Resnet18_entropy.csv'
edl_mse_q_entropy_path          = '../results/Evidential_MSE_Resnet18_quant_entropy.csv'
edl_log_entropy_path            = '../results/Evidential_LOG_Resnet18_entropy.csv'
edl_log_q_entropy_path          = '../results/Evidential_LOG_Resnet18_quant_entropy.csv'
edl_digamma_entropy_path        = '../results/Evidential_DIGAMMA_Resnet18_entropy.csv'
edl_digamma_q_entropy_path      = '../results/Evidential_DIGAMMA_Resnet18_quant_entropy.csv'
duq_entropy_path                = '../results/DUQ_ResNet_DUQ_entropy.csv'
duq_q_entropy_path              = '../results/DUQ_ResNet_DUQ_quant_entropy.csv'

         
ce_metrics_path                 = '../results/Crossentropy_Resnet18_metrics.csv'
ce_q_metrics_path               = '../results/Crossentropy_Resnet18_quant_metrics.csv'
edl_mse_metrics_path            = '../results/Evidential_MSE_Resnet18_metrics.csv'
edl_mse_q_metrics_path          = '../results/Evidential_MSE_Resnet18_quant_metrics.csv'
edl_log_metrics_path            = '../results/Evidential_LOG_Resnet18_metrics.csv'
edl_log_q_metrics_path          = '../results/Evidential_LOG_Resnet18_quant_metrics.csv'
edl_digamma_metrics_path        = '../results/Evidential_DIGAMMA_Resnet18_metrics.csv'
edl_digamma_q_metrics_path      = '../results/Evidential_DIGAMMA_Resnet18_quant_metrics.csv'
duq_metrics_path                = '../results/DUQ_ResNet_DUQ_metrics.csv'
duq_q_metrics_path              = '../results/DUQ_ResNet_DUQ_quant_metrics.csv'

file_ext = ' CIFAR10.png'
save_pth = '../results/CIFAR10/'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 

plt.rcParams['figure.dpi'] = 100
plt.rcParams['savefig.dpi'] = 300

# %%
df = pd.read_csv(ce_loss_acc_path)
epoch_no = df['epoch_no']
ce_train_loss = df['train_loss']
ce_val_loss = df['val_loss']
ce_train_acc = df['train_acc']
ce_val_acc = df['val_acc']


df1 = pd.read_csv(edl_mse_loss_acc_path)
edl_mse_train_loss = df1['train_loss']
edl_mse_val_loss = df1['val_loss']
edl_mse_train_acc = df1['train_acc']
edl_mse_val_acc = df1['val_acc']


df2 = pd.read_csv(edl_log_loss_acc_path)
edl_log_train_loss = df2['train_loss']
edl_log_val_loss = df2['val_loss']
edl_log_train_acc = df2['train_acc']
edl_log_val_acc = df2['val_acc']


df3 = pd.read_csv(edl_digamma_loss_acc_path)
edl_digamma_train_loss = df3['train_loss']
edl_digamma_val_loss = df3['val_loss']
edl_digamma_train_acc = df3['train_acc']
edl_digamma_val_acc = df3['val_acc']

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(epoch_no, ce_train_loss, label="CE")
ax.plot(epoch_no, edl_mse_train_loss, label="EDL_MSE")
ax.plot(epoch_no, edl_log_train_loss, label="EDL_LOG")
ax.plot(epoch_no, edl_digamma_train_loss, label="EDL_DIGAMMA")
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
#ax.set_title('Training loss')
ax.legend()
plt.tight_layout()
plt.show()
fig.savefig(save_pth+'TrainingLoss'+file_ext)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(epoch_no, ce_val_loss, label="CE")
ax.plot(epoch_no, edl_mse_val_loss, label="EDL_MSE")
ax.plot(epoch_no, edl_log_val_loss, label="EDL_LOG")
ax.plot(epoch_no, edl_digamma_val_loss, label="EDL_DIGAMMA")
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
#ax.set_title('Validation loss')
ax.legend()
plt.tight_layout()
plt.show()
fig.savefig(save_pth+'ValidationLoss'+file_ext)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(epoch_no, ce_train_acc, label="CE")
ax.plot(epoch_no, edl_mse_train_acc, label="EDL_MSE")
ax.plot(epoch_no, edl_log_train_acc, label="EDL_LOG")
ax.plot(epoch_no, edl_digamma_train_acc, label="EDL_DIGAMMA")
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
#ax.set_title('Training accuracy')
ax.legend()
plt.tight_layout()
plt.show()
fig.savefig(save_pth+'TrainingAccuracy'+file_ext)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(epoch_no, ce_val_acc, label="CE")
ax.plot(epoch_no, edl_mse_val_acc, label="EDL_MSE")
ax.plot(epoch_no, edl_log_val_acc, label="EDL_LOG")
ax.plot(epoch_no, edl_digamma_val_acc, label="EDL_DIGAMMA")
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
#ax.set_title('Validation accuracy')
ax.legend()
plt.tight_layout()
plt.show()
fig.savefig(save_pth+'ValidationAccuracy'+file_ext)

# %%
def plot_methods(methods, file_name):
    X = ['CE', 'CE-Q', 'EDL_MSE', 'EDL_MSE-Q', 'EDL_LOG', 'EDL_LOG-Q', 'EDL_DIGAMMA', 'EDL_DIGAMMA-Q', 'DUQ', 'DUQ-Q']
    fig, ax = plt.subplots(figsize=(5, 5))
    ax.bar(X, methods)
    ax.get_xticklabels()
    plt.xticks(rotation=30, ha='right')
    plt.ylabel("Score")
    plt.tight_layout()
    plt.show()
    fig.savefig(save_pth+file_name+file_ext)

# %%
def box_plot(data, file_name, y_label='score'):
    X = ['CE', 'CE-Q', 'EDL_MSE', 'EDL_MSE-Q', 'EDL_LOG', 'EDL_LOG-Q', 'EDL_DIGAMMA', 'EDL_DIGAMMA-Q', 'DUQ', 'DUQ-Q']
    fig, ax = plt.subplots(figsize=(5, 5))
    bp = ax.boxplot(data, patch_artist=True)    
    edge_color='blue'
    fill_color='cyan'
    for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(bp[element], color=edge_color)
    for patch in bp['boxes']:
        patch.set(facecolor=fill_color)   
    ax.set_xticklabels(X)
    plt.xticks(rotation=30, ha='right')
    plt.ylabel(y_label)
    plt.tight_layout()
    plt.show()
    fig.savefig(save_pth+file_name+file_ext)

# %% [markdown]
# # Classification Metrics

# %%
df1 = pd.read_csv(ce_metrics_path)
df2 = pd.read_csv(ce_q_metrics_path)
df3 = pd.read_csv(edl_mse_metrics_path)
df4 = pd.read_csv(edl_mse_q_metrics_path)
df5 = pd.read_csv(edl_log_metrics_path)
df6 = pd.read_csv(edl_log_q_metrics_path)
df7 = pd.read_csv(edl_digamma_metrics_path)
df8 = pd.read_csv(edl_digamma_q_metrics_path)
df9 = pd.read_csv(duq_metrics_path)
df10 = pd.read_csv(duq_q_metrics_path)

# %%
ce = df1.iloc[0]['accuracy']
ce_q = df2.iloc[0]['accuracy']
edl_mse = df3.iloc[0]['accuracy']
edl_mse_q = df4.iloc[0]['accuracy']
edl_log = df5.iloc[0]['accuracy']
edl_log_q = df6.iloc[0]['accuracy']
edl_digamma = df7.iloc[0]['accuracy']
edl_digamma_q = df8.iloc[0]['accuracy']
duq = df9.iloc[0]['accuracy']
duq_q = df10.iloc[0]['accuracy']

methods = [ce, ce_q, edl_mse, edl_mse_q, edl_log, edl_log_q, edl_digamma, edl_digamma_q, duq, duq_q]
file_name='InferenceAccuracy'
plot_methods(methods, file_name)

# %%
# ce = df1['accuracy']
# ce_q = df2['accuracy']
# edl_mse = df3['accuracy']
# edl_mse_q = df4['accuracy']
# edl_log = df5['accuracy']
# edl_log_q = df6['accuracy']
# edl_digamma = df7['accuracy']
# edl_digamma_q = df8['accuracy']
#duq = df9['accuracy']
#duq_q = df10['accuracy']

# methods = [ce, ce_q, edl_mse, edl_mse_q, edl_log, edl_log_q, edl_digamma, edl_digamma_q, duq, duq_q]
# file_name='InferenceAccuracy'
# y_label = "Score"
# box_plot(methods, file_name, y_label)

# %%
ce = df1.iloc[0]['precision']
ce_q = df2.iloc[0]['precision']
edl_mse = df3.iloc[0]['precision']
edl_mse_q = df4.iloc[0]['precision']
edl_log = df5.iloc[0]['precision']
edl_log_q = df6.iloc[0]['precision']
edl_digamma = df7.iloc[0]['precision']
edl_digamma_q = df8.iloc[0]['precision']
duq = df9.iloc[0]['precision']
duq_q = df10.iloc[0]['precision']

methods = [ce, ce_q, edl_mse, edl_mse_q, edl_log, edl_log_q, edl_digamma, edl_digamma_q, duq, duq_q]
file_name='InferencePrecision'
plot_methods(methods, file_name)

# %%
ce = df1.iloc[0]['recall_score']
ce_q = df2.iloc[0]['recall_score']
edl_mse = df3.iloc[0]['recall_score']
edl_mse_q = df4.iloc[0]['recall_score']
edl_log = df5.iloc[0]['recall_score']
edl_log_q = df6.iloc[0]['recall_score']
edl_digamma = df7.iloc[0]['recall_score']
edl_digamma_q = df8.iloc[0]['recall_score']
duq = df9.iloc[0]['recall_score']
duq_q = df10.iloc[0]['recall_score']

methods = [ce, ce_q, edl_mse, edl_mse_q, edl_log, edl_log_q, edl_digamma, edl_digamma_q, duq, duq_q]
file_name='InferenceRecall'
plot_methods(methods, file_name)

# %%
ce = df1.iloc[0]['f1score']
ce_q = df2.iloc[0]['f1score']
edl_mse = df3.iloc[0]['f1score']
edl_mse_q = df4.iloc[0]['f1score']
edl_log = df5.iloc[0]['f1score']
edl_log_q = df6.iloc[0]['f1score']
edl_digamma = df7.iloc[0]['f1score']
edl_digamma_q = df8.iloc[0]['f1score']
duq = df9.iloc[0]['f1score']
duq_q = df10.iloc[0]['f1score']

methods = [ce, ce_q, edl_mse, edl_mse_q, edl_log, edl_log_q, edl_digamma, edl_digamma_q, duq, duq_q]
file_name='InferenceF1score'
plot_methods(methods, file_name)

# %% [markdown]
# # Performance metrics

# %%
# ce = df1.iloc[0]['inferencetime']
# ce_q = df2.iloc[0]['inferencetime']
# edl_mse = df3.iloc[0]['inferencetime']
# edl_mse_q = df4.iloc[0]['inferencetime']
# edl_log = df5.iloc[0]['inferencetime']
# edl_log_q = df6.iloc[0]['inferencetime']
# edl_digamma = df7.iloc[0]['inferencetime']
# edl_digamma_q = df8.iloc[0]['inferencetime']

# methods = [ce, ce_q, edl_mse, edl_mse_q, edl_log, edl_log_q, edl_digamma, edl_digamma_q]
# file_name='InferenceTime'
# plot_methods(methods, file_name)

# %%
# ce = df1['inferencetime']
# ce_q = df2['inferencetime']
# edl_mse = df3['inferencetime']
# edl_mse_q = df4['inferencetime']
# edl_log = df5['inferencetime']
# edl_log_q = df6['inferencetime']
# edl_digamma = df7['inferencetime']
# edl_digamma_q = df8['inferencetime']

# methods = [ce, ce_q, edl_mse, edl_mse_q, edl_log, edl_log_q, edl_digamma, edl_digamma_q]
# file_name='InferenceTime'
# y_label = "Time in seconds"
# box_plot(methods, file_name, y_label)

# %%
ce = df1['inferencetime'][1:]
ce_q = df2['inferencetime'][1:]
edl_mse = df3['inferencetime'][1:]
edl_mse_q = df4['inferencetime'][1:]
edl_log = df5['inferencetime'][1:]
edl_log_q = df6['inferencetime'][1:]
edl_digamma = df7['inferencetime'][1:]
edl_digamma_q = df8['inferencetime'][1:]
duq = df9['inferencetime'][1:]
duq_q = df10['inferencetime'][1:]

methods = [ce, ce_q, edl_mse, edl_mse_q, edl_log, edl_log_q, edl_digamma, edl_digamma_q, duq, duq_q]
file_name='InferenceTime1'
y_label = "Time in milli seconds"
box_plot(methods, file_name, y_label)

# %% [markdown]
# # Uncertainty Metrics

# %%
ce = df1.iloc[0]['brierscore']
ce_q = df2.iloc[0]['brierscore']
edl_mse = df3.iloc[0]['brierscore']
edl_mse_q = df4.iloc[0]['brierscore']
edl_log = df5.iloc[0]['brierscore']
edl_log_q = df6.iloc[0]['brierscore']
edl_digamma = df7.iloc[0]['brierscore']
edl_digamma_q = df8.iloc[0]['brierscore']
duq = df9.iloc[0]['brierscore']
duq_q = df10.iloc[0]['brierscore']

methods = [ce, ce_q, edl_mse, edl_mse_q, edl_log, edl_log_q, edl_digamma, edl_digamma_q, duq, duq_q]
file_name='BrierScore'
plot_methods(methods, file_name)

# %%
ce = df1.iloc[0]['expectedcalibrationerror']
ce_q = df2.iloc[0]['expectedcalibrationerror']
edl_mse = df3.iloc[0]['expectedcalibrationerror']
edl_mse_q = df4.iloc[0]['expectedcalibrationerror']
edl_log = df5.iloc[0]['expectedcalibrationerror']
edl_log_q = df6.iloc[0]['expectedcalibrationerror']
edl_digamma = df7.iloc[0]['expectedcalibrationerror']
edl_digamma_q = df8.iloc[0]['expectedcalibrationerror']
duq = df9.iloc[0]['expectedcalibrationerror']
duq_q = df10.iloc[0]['expectedcalibrationerror']

methods = [ce, ce_q, edl_mse, edl_mse_q, edl_log, edl_log_q, edl_digamma, edl_digamma_q, duq, duq_q]
file_name='CalibrationError'
plot_methods(methods, file_name)

# %%
ce = 0
ce_q = 0
edl_mse = 0
edl_mse_q = 0
edl_log = 0
edl_log_q = 0
edl_digamma = 0
edl_digamma_q = 0
duq = df9.iloc[0]['auroc']
duq_q = df10.iloc[0]['auroc']

methods = [ce, ce_q, edl_mse, edl_mse_q, edl_log, edl_log_q, edl_digamma, edl_digamma_q, duq, duq_q]
file_name='AUROC'
plot_methods(methods, file_name)

# %%
df1 = pd.read_csv(ce_entropy_path)
df2 = pd.read_csv(ce_q_entropy_path)
df3 = pd.read_csv(edl_mse_entropy_path)
df4 = pd.read_csv(edl_mse_q_entropy_path)
df5 = pd.read_csv(edl_log_entropy_path)
df6 = pd.read_csv(edl_log_q_entropy_path)
df7 = pd.read_csv(edl_digamma_entropy_path)
df8 = pd.read_csv(edl_digamma_q_entropy_path)
df9 = pd.read_csv(duq_entropy_path)
df10 = pd.read_csv(duq_q_entropy_path)

# %%
d = {True: 'correct', False: 'incorrect'}
df1['is_prediction_correct'] = df1['is_prediction_correct'].replace(d)
df2['is_prediction_correct'] = df2['is_prediction_correct'].replace(d)
df3['is_prediction_correct'] = df3['is_prediction_correct'].replace(d)
df4['is_prediction_correct'] = df4['is_prediction_correct'].replace(d)
df5['is_prediction_correct'] = df5['is_prediction_correct'].replace(d)
df6['is_prediction_correct'] = df6['is_prediction_correct'].replace(d)
df7['is_prediction_correct'] = df7['is_prediction_correct'].replace(d)
df8['is_prediction_correct'] = df8['is_prediction_correct'].replace(d)
df9['is_prediction_correct'] = df9['is_prediction_correct'].replace(d)
df10['is_prediction_correct'] = df10['is_prediction_correct'].replace(d)

c = {'Crossentropy': 'CE', 'Crossentropy-Quant': 'CE-Q', 'Evidential_MSE': 'EDL_MSE', 'Evidential_MSE-Quant': 'EDL_MSE-Q', 'Evidential_LOG': 'EDL_LOG', 'Evidential_LOG-Quant': 'EDL_LOG-Q', 'Evidential_DIGAMMA': 'EDL_DIGAMMA', 'Evidential_DIGAMMA-Quant': 'EDL_DIGAMMA-Q', 'DUQ': 'DUQ', 'DUQ-Quant': 'DUQ-Q'}
df1['condition'] = df1['condition'].replace(c)
df2['condition'] = df2['condition'].replace(c)
df3['condition'] = df3['condition'].replace(c)
df4['condition'] = df4['condition'].replace(c)
df5['condition'] = df5['condition'].replace(c)
df6['condition'] = df6['condition'].replace(c)
df7['condition'] = df7['condition'].replace(c)
df8['condition'] = df8['condition'].replace(c)
df9['condition'] = df9['condition'].replace(c)
df10['condition'] = df10['condition'].replace(c)

df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10], ignore_index=True)

g = sns.catplot(data=df, hue="is_prediction_correct", y="entropy", x="condition", kind="violin", bw=.25, cut=0, split=True)
plt.xticks(rotation=30, ha='right')
plt.savefig(save_pth+'Entropy'+file_ext)

#g = sns.catplot(data=df, hue="is_prediction_correct", x="entropy", y="condition", kind="boxen")
